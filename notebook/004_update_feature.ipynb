# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('max_rows', 300)
pd.set_option('max_columns', 300)

import os
import glob
import pickle
sys.path.append('..')
from preprocess import get_time_stock

# %%
feature_path = '../output/feature/nb004/'
if not os.path.isdir(feature_path):
    os.makedirs(feature_path)

# %%
df_train = pd.read_pickle('/home/yoshikawa/work/kaggle/OPVP/output/feature/nb002/train.pkl')
df_test = pd.read_pickle('/home/yoshikawa/work/kaggle/OPVP/output/feature/nb002/test.pkl')

# %%
df_train.head()
# Out:
#   row_id    target  log_return_realized_volatility  log_return_mean  \
# 0    0-5  0.004136                        0.004499     7.613599e-06
# 1   0-11  0.001445                        0.001204     1.810239e-06
# 2   0-16  0.002168                        0.002369    -1.109201e-05
# 3   0-31  0.002195                        0.002574    -2.376661e-05
# 4   0-62  0.001747                        0.001894    -1.057099e-08
#
#    log_return_std  log_return_sum  log_return2_realized_volatility  \
# 0        0.000260        0.002292                         0.006999
# 1        0.000086        0.000360                         0.002476
# 2        0.000173       -0.002074                         0.004801
# 3        0.000236       -0.002828                         0.003637
# 4        0.000144       -0.000002                         0.003257
#
#    log_return2_mean  log_return2_std  log_return2_sum  wap_balance_mean  \
# 0          0.000008         0.000404         0.002325          0.000388
# ...

# %%
# list(df_train.columns)

# %%
#time_idが入っている
df_test.head()
# Out:
#    stock_id  time_id row_id  log_return_realized_volatility  log_return_mean  \
# 0         0        4    0-4                        0.000294         0.000147
# 1         0       32   0-32                             NaN              NaN
# 2         0       34   0-34                             NaN              NaN
#
#    log_return_std  log_return_sum  log_return2_realized_volatility  \
# 0        0.000208        0.000294                         0.000252
# 1             NaN             NaN                              NaN
# 2             NaN             NaN                              NaN
#
#    log_return2_mean  log_return2_std  log_return2_sum  wap_balance_mean  \
# 0          0.000139         0.000159         0.000277          0.000145
# 1               NaN              NaN              NaN               NaN
# 2               NaN              NaN              NaN               NaN
#
#    wap_balance_std  wap_balance_sum  price_spread_mean  price_spread_std  \
# ...

# %% [markdown]
# trainにtime_idを追加

# %%
df_train['time_id'] = df_train['row_id'].apply(lambda x:x.split('-')[1])
df_train['time_id']
# Out:
# 0             5
# 1            11
# 2            16
# 3            31
# 4            62
#           ...
# 428927    32751
# 428928    32753
# 428929    32758
# 428930    32763
# 428931    32767
# Name: time_id, Length: 428932, dtype: object

# %% [markdown]
# stock_id, time_idごとに集約した統計量を特徴量に追加

# %%
df_train = get_time_stock(df_train)

# %%
vol_cols = [s for s in list(df_train.columns) if 'realized_volatility' in s]
df_train[vol_cols].head(5)
# Out:
#    log_return_realized_volatility  log_return2_realized_volatility  \
# 0                        0.004499                         0.006999
# 1                        0.001204                         0.002476
# 2                        0.002369                         0.004801
# 3                        0.002574                         0.003637
# 4                        0.001894                         0.003257
#
#    log_return_realized_volatility_450  log_return2_realized_volatility_450  \
# 0                            0.001721                             0.004114
# 1                            0.000918                             0.001883
# 2                            0.001158                             0.002972
# 3                            0.000993                             0.001424
# 4                            0.001378                             0.000966
#
#    log_return_realized_volatility_300  log_return2_realized_volatility_300  \
# ...

# %%
df_train = df_train.drop(['time_id'], axis=1)

# %%
pickle.dump(df_train, open(os.path.join(feature_path, "train.pkl"), 'wb'), protocol=4)
